# %% [markdown]
# ### 트랜스포머를 이용한 주가 방향성 예측
#
# 이전 장에서 머신러닝을 이용한 주가 방향성 예측 실습을 진행했다. 이번 장에서는 딥러닝, 특히 트랜스포머 모델을 활용한 주가 방향성 예측 실습을 진행한다. 트랜스포머 모델은 자연어 처리에서 큰 성과를 거두었지만, 시계열 데이터에서도 효과적으로 사용될 수 있다.

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf # 없다면 !pip install yfinance 명령어로 설치
import ta  # 없다면 !pip install ta 명령어로 설치

# %% [markdown]
# 먼저, 필요한 라이브러리를 불러오고 데이터를 준비한다.
# 훈련 데이터 기간에 정해진 답은 없지만, 경험적으로 상승장, 하락장, 대폭락 등 여러 케이스의 정보가 담겨있을 정도로 긴 시계열이 좋다.
# 따라서 애플(AAPL) 주식 데이터를 2013년부터 2023년까지 수집하여 훈련 데이터로 사용하고, 2024년 1월부터 4월까지의 데이터를 테스트 데이터로 사용할 것이다. 이를 위해 야후 파이낸스(yfinance) 라이브러리를 사용한다.그리고 불러온 데이터에 이동 평균과 RSI 지표를 추가하여 피처를 생성하고, 결측값을 제거한다.
#
# 그 다음으로는 피처와 타깃 변수를 설정한다. 주식 데이터에서 Open, High, Low, Close, Volume, SMA_10, RSI 피처를 사용하고, 타깃 변수는 다음 날의 주가가 상승하는지 여부로 설정한다. 그리고 피처 데이터를 표준화하여 모델의 학습 효율을 높인다.머신러닝 실습에서 이미 진행한 부분이기 때문에 자세한 설명은 생략한다.

# %%
# 데이터 불러오기 (2013년부터 2023년까지 훈련 데이터, 2024년 1월부터 4월까지 테스트 데이터)
train_data = yf.download('AAPL', start='2013-01-01', end='2024-01-01')
test_data = yf.download('AAPL', start='2024-01-01', end='2024-05-01')

# 데이터 전처리 및 피처 엔지니어링
for data in [train_data, test_data]:
    data['SMA_10'] = data['Close'].rolling(window=10).mean()
    data['RSI'] = ta.momentum.RSIIndicator(data['Close']).rsi()
    data.dropna(inplace=True)

# 피처와 타깃 변수 설정
features = ['Open', 'High', 'Low', 'Close', 'Volume', 'SMA_10', 'RSI']

X_train = train_data[features].values
y_train = (train_data['Close'].shift(-1) > train_data['Close']).astype(int).values[:-1]
X_train = X_train[:-1]

X_test = test_data[features].values
y_test = (test_data['Close'].shift(-1) > test_data['Close']).astype(int).values[:-1]
X_test = X_test[:-1]

# 데이터 정규화
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
# 트랜스포머 모델 정의
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # 멀티헤드 어텐션
    x = tf.keras.layers.MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(inputs, inputs)
    x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(x)
    res = x + inputs

    # 피드포워드 네트워크
    x = tf.keras.layers.Dense(ff_dim, activation="relu")(res)
    x = tf.keras.layers.Dense(inputs.shape[-1])(x)
    x = tf.keras.layers.LayerNormalization(epsilon=1e-6)(x)
    return x + res

# %% [markdown]
# ### 트랜스포머 모델 정의
#
# 트랜스포머 모델은 자연어 처리 분야에서 처음 도입되었으나, 시계열 데이터 분석에도 매우 효과적이다. 트랜스포머 모델의 핵심 구성 요소는 멀티헤드 어텐션이다.
#
# #### 어텐션 메커니즘
# 먼저 어텐션 메커니즘에 대해 이해하는 것이 중요하다. 어텐션 메커니즘은 입력 데이터의 중요한 부분에 가중치를 부여하여 모델이 학습할 때 더 중요한 정보에 집중할 수 있도록 돕는다. 어텐션 메커니즘은 주로 다음과 같은 단계로 이루어진다:
#
# 1. 쿼리(Query), 키(Key), 값(Value): 입력 데이터는 쿼리, 키, 값 세 가지로 변환된다.
# 2. 어텐션 스코어(Attention Score): 쿼리와 키의 내적을 계산하여 어텐션 스코어를 구한다.
# 3. 어텐션 가중치(Attention Weight): 어텐션 스코어를 소프트맥스 함수에 입력하여 가중치를 구한다.
# 4. 어텐션 출력(Attention Output): 어텐션 가중치와 값의 가중 합을 구하여 최종 출력을 계산한다.
# 5. 어텐션 메커니즘의 주요 아이디어는 중요한 부분에 더 집중하고, 덜 중요한 부분은 덜 집중하는 것이다.
#
# #### 멀티헤드 어텐션
# **멀티헤드 어텐션(Multi-Head Attention)**은 여러 개의 어텐션 메커니즘을 병렬로 사용하여 다양한 표현을 학습할 수 있도록 한다. 각 어텐션 헤드는 서로 다른 부분에 주의를 기울이며, 이를 통해 모델이 더 풍부한 표현을 학습할 수 있다.
#
# 멀티헤드 어텐션의 주요 구성 요소는 다음과 같다:
#
# - 헤드(Head): 각 헤드는 독립적인 어텐션 메커니즘을 가지고 있다.
# - 병렬 계산(Parallel Computation): 여러 헤드를 병렬로 계산하여 다양한 패턴을 동시에 학습한다.
# - 결합(Concatenation): 각 헤드의 출력을 결합하여 최종 출력을 만든다.
# 멀티헤드 어텐션은 다양한 패턴을 동시에 학습할 수 있게 하여, 모델의 성능을 크게 향상시킨다.
#
# 아래 코드에서, 멀티헤드 어텐션은 tf.keras.layers.MultiHeadAttention 레이어를 통해 구현된다. 이 레이어는 입력 데이터의 여러 부분에 주의를 기울여 다양한 패턴을 학습할 수 있도록 한다.
#
# #### 트랜스포머 인코더 정의
# 트랜스포머 인코더는 멀티헤드 어텐션과 피드포워드 네트워크로 구성된다. 인코더는 입력 데이터를 여러 번 처리하여 최종 출력을 생성한다. 각 레이어는 다음과 같이 구성된다:
#
# 1. 멀티헤드 어텐션: 입력 데이터의 여러 부분에 동시에 주의를 기울여 중요한 패턴을 학습한다.
# 2. LayerNormalization: 각 레이어의 출력을 정규화하여 학습을 안정화하고 속도를 높인다.
# 3. 피드포워드 네트워크: 각 타임스텝의 출력을 더 복잡한 특징으로 변환한다.

# %%
def build_model(input_shape, head_size, num_heads, ff_dim, num_transformer_blocks, mlp_units, dropout=0, mlp_dropout=0):
    inputs = tf.keras.layers.Input(shape=input_shape)
    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = tf.keras.layers.Flatten()(x)
    for dim in mlp_units:
        x = tf.keras.layers.Dense(dim, activation="relu")(x)
        x = tf.keras.layers.Dropout(mlp_dropout)(x)
    outputs = tf.keras.layers.Dense(1, activation="sigmoid")(x)
    return tf.keras.Model(inputs, outputs)

# %% [markdown]
# #### 모델 빌드 함수 정의
# 이제 트랜스포머 인코더를 여러 층 쌓아 트랜스포머 모델을 구성한다. 또한, Flatten 레이어와 MLP(Multi-Layer Perceptron) 레이어를 추가하여 최종 출력을 생성한다. MLP 레이어에 드롭아웃을 적용하여 과적합을 방지한다.
#
# #### 응용 방법
# 트랜스포머 모델을 사용하여 시계열 데이터를 분석할 때, 다음과 같은 방법으로 모델의 성능을 최적화하고 분석 결과를 향상시킬 수 있다.
#
# 첫째, 다양한 하이퍼파라미터를 조정하는 것이 중요하다. 예를 들어, 멀티헤드 어텐션의 헤드 수를 조정함으로써 모델이 데이터를 바라보는 관점을 다양화할 수 있다. 헤드 수를 늘리면 모델이 더 다양한 패턴을 학습할 수 있지만, 계산 비용이 증가한다는 점을 염두에 두어야 한다. 또한, 피드포워드 네트워크의 차원을 조정하여 모델의 복잡성을 조절할 수 있다. 피드포워드 네트워크의 차원을 늘리면 모델이 더 복잡한 패턴을 학습할 수 있지만, 과적합의 위험도 증가한다. 마지막으로, 드롭아웃 비율을 조정하여 모델의 일반화 능력을 향상시킬 수 있다. 드롭아웃 비율을 적절히 조정하면 과적합을 방지하고 모델의 성능을 안정화할 수 있다.
#
# 둘째, 데이터 전처리를 통해 모델의 성능을 향상시킬 수 있다. 입력 데이터를 정규화하여 데이터의 스케일을 맞추면 모델이 더 빠르고 안정적으로 학습할 수 있다. 또한, 결측값을 처리하여 데이터의 완전성을 확보하는 것도 중요하다. 결측값이 있는 데이터를 그대로 사용할 경우, 모델의 성능이 저하될 수 있다. 이를 방지하기 위해 결측값을 적절히 처리하는 방법을 고려해야 한다.
#
# 셋째, 모델 튜닝을 통해 최적의 하이퍼파라미터를 찾는 과정이 필요하다. 교차 검증을 사용하면 데이터의 특정 부분에만 의존하지 않고 모델의 성능을 평가할 수 있다. 이를 통해 모델이 일반화된 성능을 가지도록 도울 수 있다. 또한, 그리드 서치를 통해 다양한 하이퍼파라미터 조합을 테스트하여 최적의 조합을 찾을 수 있다. 이 과정을 통해 모델의 성능을 최대화할 수 있다.
#
# 트랜스포머 모델은 복잡한 시계열 패턴을 효과적으로 학습할 수 있어, 다양한 금융 데이터 분석에 유용하게 사용될 수 있다. 이러한 응용 방법을 통해 트랜스포머 모델을 최적화하고, 이를 바탕으로 다양한 투자 전략을 개발할 수 있다.

# %%
# 모델 생성
input_shape = (X_train.shape[1], 1)
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

model = build_model(
    input_shape,
    head_size=256,
    num_heads=4,
    ff_dim=4,
    num_transformer_blocks=4,
    mlp_units=[128],
    mlp_dropout=0.4,
    dropout=0.25
)

model.compile(loss="binary_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), metrics=["accuracy"])
model.summary()
# Out:
# Model: "functional_7"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 7, 1)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 7, 1)      │      7,169 │ input_layer_3[0]… │
# │ (MultiHeadAttentio… │                   │            │ input_layer_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 7, 1)      │          2 │ multi_head_atten… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_24 (Add)        │ (None, 7, 1)      │          0 │ layer_normalizat… │
# │                     │                   │            │ input_layer_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_30 (Dense)    │ (None, 7, 4)      │          8 │ add_24[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_31 (Dense)    │ (None, 7, 1)      │          5 │ dense_30[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 7, 1)      │          2 │ dense_31[0][0]    │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_25 (Add)        │ (None, 7, 1)      │          0 │ layer_normalizat… │
# │                     │                   │            │ add_24[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 7, 1)      │      7,169 │ add_25[0][0],     │
# │ (MultiHeadAttentio… │                   │            │ add_25[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 7, 1)      │          2 │ multi_head_atten… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_26 (Add)        │ (None, 7, 1)      │          0 │ layer_normalizat… │
# │                     │                   │            │ add_25[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_32 (Dense)    │ (None, 7, 4)      │          8 │ add_26[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_33 (Dense)    │ (None, 7, 1)      │          5 │ dense_32[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 7, 1)      │          2 │ dense_33[0][0]    │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_27 (Add)        │ (None, 7, 1)      │          0 │ layer_normalizat… │
# │                     │                   │            │ add_26[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 7, 1)      │      7,169 │ add_27[0][0],     │
# │ (MultiHeadAttentio… │                   │            │ add_27[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 7, 1)      │          2 │ multi_head_atten… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_28 (Add)        │ (None, 7, 1)      │          0 │ layer_normalizat… │
# │                     │                   │            │ add_27[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_34 (Dense)    │ (None, 7, 4)      │          8 │ add_28[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_35 (Dense)    │ (None, 7, 1)      │          5 │ dense_34[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 7, 1)      │          2 │ dense_35[0][0]    │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_29 (Add)        │ (None, 7, 1)      │          0 │ layer_normalizat… │
# │                     │                   │            │ add_28[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 7, 1)      │      7,169 │ add_29[0][0],     │
# │ (MultiHeadAttentio… │                   │            │ add_29[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 7, 1)      │          2 │ multi_head_atten… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_30 (Add)        │ (None, 7, 1)      │          0 │ layer_normalizat… │
# │                     │                   │            │ add_29[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_36 (Dense)    │ (None, 7, 4)      │          8 │ add_30[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_37 (Dense)    │ (None, 7, 1)      │          5 │ dense_36[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 7, 1)      │          2 │ dense_37[0][0]    │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_31 (Add)        │ (None, 7, 1)      │          0 │ layer_normalizat… │
# │                     │                   │            │ add_30[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_3 (Flatten) │ (None, 7)         │          0 │ add_31[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_38 (Dense)    │ (None, 128)       │      1,024 │ flatten_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_19          │ (None, 128)       │          0 │ dense_38[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_39 (Dense)    │ (None, 1)         │        129 │ dropout_19[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 29,897 (116.79 KB)
#  Trainable params: 29,897 (116.79 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #### 모델 컴파일 및 학습
# 트랜스포머 모델을 구축하고, 컴파일한다. 손실 함수로는 binary_crossentropy를 사용하고, 최적화 도구로 Adam 옵티마이저를 사용한다. 200 에포크 동안 모델을 학습시키고, 학습 곡선을 그려서 모델의 학습 상태를 모니터링한다.

# %%
# 모델 학습 (에포크 수 증가)
history = model.fit(X_train, y_train, validation_split=0.2, epochs=200, batch_size=32)

# 학습 곡선 시각화
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()
# Out:
# Epoch 1/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4965 - loss: 0.6992 - val_accuracy: 0.5209 - val_loss: 0.6914
# Epoch 2/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5192 - loss: 0.6922 - val_accuracy: 0.5209 - val_loss: 0.6914
# Epoch 3/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5197 - loss: 0.6935 - val_accuracy: 0.5227 - val_loss: 0.6914
# Epoch 4/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5225 - loss: 0.6933 - val_accuracy: 0.5227 - val_loss: 0.6914
# Epoch 5/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5462 - loss: 0.6895 - val_accuracy: 0.5227 - val_loss: 0.6914
# Epoch 6/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5240 - loss: 0.6942 - val_accuracy: 0.5191 - val_loss: 0.6915
# Epoch 7/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5284 - loss: 0.6935 - val_accuracy: 0.5227 - val_loss: 0.6914
# Epoch 8/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5272 - loss: 0.6939 - val_accuracy: 0.5227 - val_loss: 0.6914
# Epoch 9/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5265 - loss: 0.6928 - val_accuracy: 0.5154 - val_loss: 0.6914
# Epoch 10/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5328 - loss: 0.6914 - val_accuracy: 0.5263 - val_loss: 0.6914
# Epoch 11/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5303 - loss: 0.6927 - val_accuracy: 0.5209 - val_loss: 0.6914
# Epoch 12/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5102 - loss: 0.6962 - val_accuracy: 0.5191 - val_loss: 0.6914
# Epoch 13/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5267 - loss: 0.6908 - val_accuracy: 0.5209 - val_loss: 0.6915
# Epoch 14/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5142 - loss: 0.6934 - val_accuracy: 0.5245 - val_loss: 0.6915
# Epoch 15/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5398 - loss: 0.6920 - val_accuracy: 0.5227 - val_loss: 0.6915
# Epoch 16/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5103 - loss: 0.6917 - val_accuracy: 0.5263 - val_loss: 0.6916
# Epoch 17/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5538 - loss: 0.6873 - val_accuracy: 0.5245 - val_loss: 0.6916
# Epoch 18/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5277 - loss: 0.6914 - val_accuracy: 0.5172 - val_loss: 0.6916
# Epoch 19/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5314 - loss: 0.6939 - val_accuracy: 0.5227 - val_loss: 0.6916
# Epoch 20/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5174 - loss: 0.6924 - val_accuracy: 0.5172 - val_loss: 0.6918
# Epoch 21/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5511 - loss: 0.6915 - val_accuracy: 0.5263 - val_loss: 0.6917
# Epoch 22/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4977 - loss: 0.7003 - val_accuracy: 0.5191 - val_loss: 0.6917
# Epoch 23/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5151 - loss: 0.6945 - val_accuracy: 0.5191 - val_loss: 0.6917
# Epoch 24/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5087 - loss: 0.6948 - val_accuracy: 0.5281 - val_loss: 0.6916
# Epoch 25/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4952 - loss: 0.7005 - val_accuracy: 0.5263 - val_loss: 0.6917
# Epoch 26/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5590 - loss: 0.6853 - val_accuracy: 0.5172 - val_loss: 0.6917
# Epoch 27/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5361 - loss: 0.6912 - val_accuracy: 0.5245 - val_loss: 0.6917
# Epoch 28/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5424 - loss: 0.6895 - val_accuracy: 0.5209 - val_loss: 0.6917
# Epoch 29/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5123 - loss: 0.6957 - val_accuracy: 0.5281 - val_loss: 0.6916
# Epoch 30/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5259 - loss: 0.6964 - val_accuracy: 0.5191 - val_loss: 0.6916
# Epoch 31/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5424 - loss: 0.6881 - val_accuracy: 0.5263 - val_loss: 0.6916
# Epoch 32/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5383 - loss: 0.6903 - val_accuracy: 0.5263 - val_loss: 0.6917
# Epoch 33/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5212 - loss: 0.6926 - val_accuracy: 0.5154 - val_loss: 0.6917
# Epoch 34/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5542 - loss: 0.6883 - val_accuracy: 0.5227 - val_loss: 0.6917
# Epoch 35/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5009 - loss: 0.6974 - val_accuracy: 0.5245 - val_loss: 0.6917
# Epoch 36/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5376 - loss: 0.6885 - val_accuracy: 0.5227 - val_loss: 0.6917
# Epoch 37/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5327 - loss: 0.6913 - val_accuracy: 0.5172 - val_loss: 0.6918
# Epoch 38/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5379 - loss: 0.6908 - val_accuracy: 0.5245 - val_loss: 0.6918
# Epoch 39/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5085 - loss: 0.6959 - val_accuracy: 0.5154 - val_loss: 0.6918
# Epoch 40/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5122 - loss: 0.6967 - val_accuracy: 0.5154 - val_loss: 0.6919
# Epoch 41/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4928 - loss: 0.6946 - val_accuracy: 0.5154 - val_loss: 0.6917
# Epoch 42/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5160 - loss: 0.6939 - val_accuracy: 0.5209 - val_loss: 0.6917
# Epoch 43/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5547 - loss: 0.6873 - val_accuracy: 0.5245 - val_loss: 0.6917
# Epoch 44/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5206 - loss: 0.6930 - val_accuracy: 0.5172 - val_loss: 0.6918
# Epoch 45/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5283 - loss: 0.6933 - val_accuracy: 0.5172 - val_loss: 0.6917
# Epoch 46/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5171 - loss: 0.6944 - val_accuracy: 0.5245 - val_loss: 0.6916
# Epoch 47/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5300 - loss: 0.6900 - val_accuracy: 0.5227 - val_loss: 0.6916
# Epoch 48/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5289 - loss: 0.6926 - val_accuracy: 0.5263 - val_loss: 0.6915
# Epoch 49/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5485 - loss: 0.6882 - val_accuracy: 0.5154 - val_loss: 0.6916
# Epoch 50/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5134 - loss: 0.6949 - val_accuracy: 0.5172 - val_loss: 0.6916
# Epoch 51/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5325 - loss: 0.6913 - val_accuracy: 0.5172 - val_loss: 0.6916
# Epoch 52/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5250 - loss: 0.6930 - val_accuracy: 0.5245 - val_loss: 0.6916
# Epoch 53/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5312 - loss: 0.6911 - val_accuracy: 0.5172 - val_loss: 0.6917
# Epoch 54/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5284 - loss: 0.6936 - val_accuracy: 0.5136 - val_loss: 0.6916
# Epoch 55/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5525 - loss: 0.6895 - val_accuracy: 0.5154 - val_loss: 0.6916
# Epoch 56/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5461 - loss: 0.6950 - val_accuracy: 0.5245 - val_loss: 0.6915
# Epoch 57/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5312 - loss: 0.6923 - val_accuracy: 0.5154 - val_loss: 0.6919
# Epoch 58/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5277 - loss: 0.6910 - val_accuracy: 0.5154 - val_loss: 0.6918
# Epoch 59/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5376 - loss: 0.6905 - val_accuracy: 0.5154 - val_loss: 0.6917
# Epoch 60/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5197 - loss: 0.6930 - val_accuracy: 0.5136 - val_loss: 0.6917
# Epoch 61/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5418 - loss: 0.6892 - val_accuracy: 0.5154 - val_loss: 0.6917
# Epoch 62/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5348 - loss: 0.6906 - val_accuracy: 0.5154 - val_loss: 0.6918
# Epoch 63/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5405 - loss: 0.6887 - val_accuracy: 0.5154 - val_loss: 0.6919
# Epoch 64/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5332 - loss: 0.6930 - val_accuracy: 0.5118 - val_loss: 0.6916
# Epoch 65/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5539 - loss: 0.6858 - val_accuracy: 0.5118 - val_loss: 0.6917
# Epoch 66/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5423 - loss: 0.6898 - val_accuracy: 0.5118 - val_loss: 0.6917
# Epoch 67/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5393 - loss: 0.6903 - val_accuracy: 0.5209 - val_loss: 0.6916
# Epoch 68/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5173 - loss: 0.6913 - val_accuracy: 0.5172 - val_loss: 0.6916
# Epoch 69/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5245 - loss: 0.6908 - val_accuracy: 0.5154 - val_loss: 0.6917
# Epoch 70/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5198 - loss: 0.6897 - val_accuracy: 0.5191 - val_loss: 0.6916
# Epoch 71/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5209 - loss: 0.6963 - val_accuracy: 0.5136 - val_loss: 0.6918
# Epoch 72/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5185 - loss: 0.6921 - val_accuracy: 0.5172 - val_loss: 0.6916
# Epoch 73/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5377 - loss: 0.6906 - val_accuracy: 0.5209 - val_loss: 0.6915
# Epoch 74/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5271 - loss: 0.6913 - val_accuracy: 0.5154 - val_loss: 0.6915
# Epoch 75/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5242 - loss: 0.6924 - val_accuracy: 0.5191 - val_loss: 0.6915
# Epoch 76/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5362 - loss: 0.6878 - val_accuracy: 0.5191 - val_loss: 0.6914
# Epoch 77/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5431 - loss: 0.6894 - val_accuracy: 0.5191 - val_loss: 0.6915
# Epoch 78/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5292 - loss: 0.6930 - val_accuracy: 0.5172 - val_loss: 0.6915
# Epoch 79/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5007 - loss: 0.6976 - val_accuracy: 0.5100 - val_loss: 0.6917
# Epoch 80/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5278 - loss: 0.6888 - val_accuracy: 0.5209 - val_loss: 0.6914
# Epoch 81/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5540 - loss: 0.6916 - val_accuracy: 0.5191 - val_loss: 0.6915
# Epoch 82/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5343 - loss: 0.6921 - val_accuracy: 0.5154 - val_loss: 0.6915
# Epoch 83/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5406 - loss: 0.6915 - val_accuracy: 0.5154 - val_loss: 0.6916
# Epoch 84/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5132 - loss: 0.6942 - val_accuracy: 0.5154 - val_loss: 0.6915
# Epoch 85/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5319 - loss: 0.6920 - val_accuracy: 0.5136 - val_loss: 0.6917
# Epoch 86/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5406 - loss: 0.6894 - val_accuracy: 0.5154 - val_loss: 0.6916
# Epoch 87/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5110 - loss: 0.6918 - val_accuracy: 0.5118 - val_loss: 0.6917
# Epoch 88/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5173 - loss: 0.6931 - val_accuracy: 0.5100 - val_loss: 0.6917
# Epoch 89/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5384 - loss: 0.6889 - val_accuracy: 0.5136 - val_loss: 0.6917
# Epoch 90/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5290 - loss: 0.6923 - val_accuracy: 0.5154 - val_loss: 0.6917
# Epoch 91/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5147 - loss: 0.6920 - val_accuracy: 0.5118 - val_loss: 0.6915
# Epoch 92/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4903 - loss: 0.6949 - val_accuracy: 0.5172 - val_loss: 0.6914
# Epoch 93/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5321 - loss: 0.6906 - val_accuracy: 0.5172 - val_loss: 0.6915
# Epoch 94/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5223 - loss: 0.6912 - val_accuracy: 0.5154 - val_loss: 0.6918
# Epoch 95/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5278 - loss: 0.6933 - val_accuracy: 0.5154 - val_loss: 0.6916
# Epoch 96/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5669 - loss: 0.6871 - val_accuracy: 0.5154 - val_loss: 0.6916
# Epoch 97/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5156 - loss: 0.6968 - val_accuracy: 0.5191 - val_loss: 0.6915
# Epoch 98/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5304 - loss: 0.6920 - val_accuracy: 0.5154 - val_loss: 0.6918
# Epoch 99/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5235 - loss: 0.6937 - val_accuracy: 0.5172 - val_loss: 0.6916
# Epoch 100/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5370 - loss: 0.6892 - val_accuracy: 0.5136 - val_loss: 0.6918
# Epoch 101/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5266 - loss: 0.6916 - val_accuracy: 0.5172 - val_loss: 0.6916
# Epoch 102/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5244 - loss: 0.6921 - val_accuracy: 0.5136 - val_loss: 0.6917
# Epoch 103/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5495 - loss: 0.6890 - val_accuracy: 0.5154 - val_loss: 0.6916
# Epoch 104/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5397 - loss: 0.6900 - val_accuracy: 0.5136 - val_loss: 0.6917
# Epoch 105/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5154 - loss: 0.6928 - val_accuracy: 0.5136 - val_loss: 0.6917
# Epoch 106/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5439 - loss: 0.6884 - val_accuracy: 0.5118 - val_loss: 0.6919
# Epoch 107/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5001 - loss: 0.6965 - val_accuracy: 0.5136 - val_loss: 0.6917
# Epoch 108/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5498 - loss: 0.6898 - val_accuracy: 0.5100 - val_loss: 0.6919
# Epoch 109/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5290 - loss: 0.6906 - val_accuracy: 0.5154 - val_loss: 0.6918
# Epoch 110/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5281 - loss: 0.6907 - val_accuracy: 0.5154 - val_loss: 0.6917
# Epoch 111/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5351 - loss: 0.6875 - val_accuracy: 0.5191 - val_loss: 0.6917
# Epoch 112/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5404 - loss: 0.6903 - val_accuracy: 0.5136 - val_loss: 0.6916
# Epoch 113/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5335 - loss: 0.6920 - val_accuracy: 0.5191 - val_loss: 0.6917
# Epoch 114/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5434 - loss: 0.6893 - val_accuracy: 0.5245 - val_loss: 0.6917
# Epoch 115/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5403 - loss: 0.6893 - val_accuracy: 0.5191 - val_loss: 0.6918
# Epoch 116/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5431 - loss: 0.6884 - val_accuracy: 0.5064 - val_loss: 0.6921
# Epoch 117/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5220 - loss: 0.6933 - val_accuracy: 0.5100 - val_loss: 0.6919
# Epoch 118/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5316 - loss: 0.6889 - val_accuracy: 0.5191 - val_loss: 0.6917
# Epoch 119/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5376 - loss: 0.6900 - val_accuracy: 0.5136 - val_loss: 0.6918
# Epoch 120/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5362 - loss: 0.6941 - val_accuracy: 0.5209 - val_loss: 0.6917
# Epoch 121/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5346 - loss: 0.6890 - val_accuracy: 0.5172 - val_loss: 0.6917
# Epoch 122/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5160 - loss: 0.6951 - val_accuracy: 0.5209 - val_loss: 0.6917
# Epoch 123/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5310 - loss: 0.6897 - val_accuracy: 0.5172 - val_loss: 0.6916
# Epoch 124/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5387 - loss: 0.6905 - val_accuracy: 0.5136 - val_loss: 0.6918
# Epoch 125/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5530 - loss: 0.6910 - val_accuracy: 0.5209 - val_loss: 0.6916
# Epoch 126/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5363 - loss: 0.6901 - val_accuracy: 0.5100 - val_loss: 0.6919
# Epoch 127/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5214 - loss: 0.6905 - val_accuracy: 0.5209 - val_loss: 0.6916
# Epoch 128/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5232 - loss: 0.6918 - val_accuracy: 0.5191 - val_loss: 0.6917
# Epoch 129/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5322 - loss: 0.6899 - val_accuracy: 0.5172 - val_loss: 0.6916
# Epoch 130/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5429 - loss: 0.6886 - val_accuracy: 0.5100 - val_loss: 0.6918
# Epoch 131/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5404 - loss: 0.6896 - val_accuracy: 0.5172 - val_loss: 0.6915
# Epoch 132/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5181 - loss: 0.6909 - val_accuracy: 0.5172 - val_loss: 0.6915
# Epoch 133/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5459 - loss: 0.6897 - val_accuracy: 0.5136 - val_loss: 0.6914
# Epoch 134/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5485 - loss: 0.6885 - val_accuracy: 0.5100 - val_loss: 0.6918
# Epoch 135/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5388 - loss: 0.6932 - val_accuracy: 0.5118 - val_loss: 0.6917
# Epoch 136/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5389 - loss: 0.6894 - val_accuracy: 0.5209 - val_loss: 0.6914
# Epoch 137/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5457 - loss: 0.6900 - val_accuracy: 0.5082 - val_loss: 0.6916
# Epoch 138/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5168 - loss: 0.6941 - val_accuracy: 0.5209 - val_loss: 0.6914
# Epoch 139/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5453 - loss: 0.6871 - val_accuracy: 0.5209 - val_loss: 0.6915
# Epoch 140/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5331 - loss: 0.6895 - val_accuracy: 0.5082 - val_loss: 0.6918
# Epoch 141/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5271 - loss: 0.6927 - val_accuracy: 0.5136 - val_loss: 0.6917
# Epoch 142/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5359 - loss: 0.6887 - val_accuracy: 0.5191 - val_loss: 0.6916
# Epoch 143/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5285 - loss: 0.6919 - val_accuracy: 0.5172 - val_loss: 0.6917
# Epoch 144/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5191 - loss: 0.6936 - val_accuracy: 0.5118 - val_loss: 0.6918
# Epoch 145/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5265 - loss: 0.6909 - val_accuracy: 0.5118 - val_loss: 0.6918
# Epoch 146/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5492 - loss: 0.6861 - val_accuracy: 0.5172 - val_loss: 0.6917
# Epoch 147/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5534 - loss: 0.6879 - val_accuracy: 0.5191 - val_loss: 0.6918
# Epoch 148/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5393 - loss: 0.6895 - val_accuracy: 0.5136 - val_loss: 0.6920
# Epoch 149/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5081 - loss: 0.6960 - val_accuracy: 0.5136 - val_loss: 0.6919
# Epoch 150/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5250 - loss: 0.6915 - val_accuracy: 0.5172 - val_loss: 0.6917
# Epoch 151/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5358 - loss: 0.6905 - val_accuracy: 0.5100 - val_loss: 0.6918
# Epoch 152/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5200 - loss: 0.6938 - val_accuracy: 0.5064 - val_loss: 0.6920
# Epoch 153/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5289 - loss: 0.6925 - val_accuracy: 0.5100 - val_loss: 0.6919
# Epoch 154/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5362 - loss: 0.6908 - val_accuracy: 0.5136 - val_loss: 0.6922
# Epoch 155/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5401 - loss: 0.6896 - val_accuracy: 0.5191 - val_loss: 0.6917
# Epoch 156/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5258 - loss: 0.6928 - val_accuracy: 0.5154 - val_loss: 0.6917
# Epoch 157/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5267 - loss: 0.6934 - val_accuracy: 0.5191 - val_loss: 0.6917
# Epoch 158/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5317 - loss: 0.6906 - val_accuracy: 0.5100 - val_loss: 0.6920
# Epoch 159/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5326 - loss: 0.6911 - val_accuracy: 0.5118 - val_loss: 0.6918
# Epoch 160/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5270 - loss: 0.6913 - val_accuracy: 0.5136 - val_loss: 0.6918
# Epoch 161/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5341 - loss: 0.6900 - val_accuracy: 0.5082 - val_loss: 0.6921
# Epoch 162/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5364 - loss: 0.6875 - val_accuracy: 0.5172 - val_loss: 0.6916
# Epoch 163/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5377 - loss: 0.6912 - val_accuracy: 0.5082 - val_loss: 0.6920
# Epoch 164/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5361 - loss: 0.6921 - val_accuracy: 0.5191 - val_loss: 0.6917
# Epoch 165/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5410 - loss: 0.6894 - val_accuracy: 0.5227 - val_loss: 0.6917
# Epoch 166/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5253 - loss: 0.6920 - val_accuracy: 0.5245 - val_loss: 0.6916
# Epoch 167/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5510 - loss: 0.6879 - val_accuracy: 0.5191 - val_loss: 0.6917
# Epoch 168/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5477 - loss: 0.6884 - val_accuracy: 0.5227 - val_loss: 0.6917
# Epoch 169/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5576 - loss: 0.6912 - val_accuracy: 0.5100 - val_loss: 0.6919
# Epoch 170/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5424 - loss: 0.6875 - val_accuracy: 0.5191 - val_loss: 0.6917
# Epoch 171/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.5470 - loss: 0.6896 - val_accuracy: 0.5191 - val_loss: 0.6918
# Epoch 172/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5452 - loss: 0.6879 - val_accuracy: 0.5172 - val_loss: 0.6918
# Epoch 173/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5280 - loss: 0.6928 - val_accuracy: 0.5118 - val_loss: 0.6918
# Epoch 174/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5447 - loss: 0.6888 - val_accuracy: 0.5136 - val_loss: 0.6921
# Epoch 175/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5460 - loss: 0.6889 - val_accuracy: 0.5064 - val_loss: 0.6920
# Epoch 176/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5438 - loss: 0.6870 - val_accuracy: 0.5045 - val_loss: 0.6921
# Epoch 177/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5476 - loss: 0.6882 - val_accuracy: 0.5045 - val_loss: 0.6921
# Epoch 178/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5687 - loss: 0.6859 - val_accuracy: 0.5118 - val_loss: 0.6923
# Epoch 179/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5298 - loss: 0.6928 - val_accuracy: 0.5136 - val_loss: 0.6926
# Epoch 180/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5487 - loss: 0.6887 - val_accuracy: 0.5082 - val_loss: 0.6920
# Epoch 181/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5411 - loss: 0.6899 - val_accuracy: 0.5100 - val_loss: 0.6918
# Epoch 182/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5358 - loss: 0.6923 - val_accuracy: 0.5136 - val_loss: 0.6922
# Epoch 183/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5204 - loss: 0.6951 - val_accuracy: 0.5082 - val_loss: 0.6921
# Epoch 184/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5505 - loss: 0.6893 - val_accuracy: 0.5154 - val_loss: 0.6923
# Epoch 185/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5308 - loss: 0.6899 - val_accuracy: 0.5064 - val_loss: 0.6921
# Epoch 186/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5392 - loss: 0.6920 - val_accuracy: 0.5064 - val_loss: 0.6921
# Epoch 187/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5377 - loss: 0.6903 - val_accuracy: 0.5082 - val_loss: 0.6922
# Epoch 188/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5395 - loss: 0.6894 - val_accuracy: 0.5118 - val_loss: 0.6921
# Epoch 189/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5251 - loss: 0.6913 - val_accuracy: 0.5064 - val_loss: 0.6922
# Epoch 190/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5381 - loss: 0.6881 - val_accuracy: 0.5100 - val_loss: 0.6921
# Epoch 191/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5315 - loss: 0.6907 - val_accuracy: 0.5136 - val_loss: 0.6924
# Epoch 192/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5254 - loss: 0.6912 - val_accuracy: 0.5082 - val_loss: 0.6921
# Epoch 193/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5251 - loss: 0.6905 - val_accuracy: 0.5136 - val_loss: 0.6924
# Epoch 194/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5285 - loss: 0.6919 - val_accuracy: 0.5118 - val_loss: 0.6924
# Epoch 195/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5284 - loss: 0.6904 - val_accuracy: 0.5136 - val_loss: 0.6925
# Epoch 196/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5425 - loss: 0.6885 - val_accuracy: 0.5082 - val_loss: 0.6924
# Epoch 197/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5233 - loss: 0.6933 - val_accuracy: 0.5082 - val_loss: 0.6922
# Epoch 198/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5095 - loss: 0.6946 - val_accuracy: 0.5064 - val_loss: 0.6922
# Epoch 199/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5498 - loss: 0.6867 - val_accuracy: 0.5082 - val_loss: 0.6922
# Epoch 200/200
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5227 - loss: 0.6928 - val_accuracy: 0.5136 - val_loss: 0.6925

# %% [markdown]
# #### 학습 곡선 시각화
# 학습 곡선을 통해 과적합 여부를 확인할 수 있다. 이 예제에서는 검증 손실이 거의 일정하므로 과적합이 의심된다. 정규화 기법을 추가하거나 모델의 복잡도를 조정하여 이를 개선할 수 있다.

# %%
# 훈련 데이터 결과
y_train_pred = model.predict(X_train)
threshold = y_train.mean()  # 훈련 데이터 비율로 트레시홀드 설정
y_train_pred_threshold = (y_train_pred > threshold).astype(int)
accuracy_train = accuracy_score(y_train, y_train_pred_threshold)
conf_matrix_train = confusion_matrix(y_train, y_train_pred_threshold)
print(f"훈련 데이터 정확도: {accuracy_train:.2f}")
print("훈련 데이터 혼동 행렬:")
print(conf_matrix_train)
print("\n훈련 데이터 분류 리포트:")
print(classification_report(y_train, y_train_pred_threshold))
# Out:
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 훈련 데이터 정확도: 0.53
# 훈련 데이터 혼동 행렬:
# [[707 599]
#  [698 750]]
#
# 훈련 데이터 분류 리포트:
#               precision    recall  f1-score   support
#
#            0       0.50      0.54      0.52      1306
#            1       0.56      0.52      0.54      1448
#
#     accuracy                           0.53      2754
#    macro avg       0.53      0.53      0.53      2754
# weighted avg       0.53      0.53      0.53      2754

# %%
# 테스트 데이터 결과
y_pred = model.predict(X_test)
y_pred_threshold = (y_pred > threshold).astype(int)
accuracy_test = accuracy_score(y_test, y_pred_threshold)
conf_matrix_test = confusion_matrix(y_test, y_pred_threshold)
print(f"테스트 데이터 정확도: {accuracy_test:.2f}")
print("테스트 데이터 혼동 행렬:")
print(conf_matrix_test)
print("\n테스트 데이터 분류 리포트:")
print(classification_report(y_test, y_pred_threshold))
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 436ms/step
# 테스트 데이터 정확도: 0.68
# 테스트 데이터 혼동 행렬:
# [[32  9]
#  [13 15]]
#
# 테스트 데이터 분류 리포트:
#               precision    recall  f1-score   support
#
#            0       0.71      0.78      0.74        41
#            1       0.62      0.54      0.58        28
#
#     accuracy                           0.68        69
#    macro avg       0.67      0.66      0.66        69
# weighted avg       0.68      0.68      0.68        69

# %%
# 훈련 데이터와 테스트 데이터의 클래스 분포 확인
print("훈련 데이터 클래스 분포:")
print(pd.Series(y_train).value_counts())
print("\n테스트 데이터 클래스 분포:")
print(pd.Series(y_test).value_counts())
# Out:
# 훈련 데이터 클래스 분포:
# 1    1448
# 0    1306
# Name: count, dtype: int64
#
# 테스트 데이터 클래스 분포:
# 0    41
# 1    28
# Name: count, dtype: int64

# %% [markdown]
# #### 모델 평가
# 훈련 데이터와 테스트 데이터에서의 성능을 평가한 결과, 훈련 데이터의 정확도는 53% 정도, 테스트 데이터의 정확도는 68% 정도이다. (위에서 확인한 분포로 보아서는) 이는 테스트 데이터가 상승장에 편향되어 있기 때문일 수 있다. 따라서 실제로 '정확도'가 아닌 수익률을 봐야 한다. 또한 벤치마크 지표가 필요하다. 예를 들어 buy and hold 전략이 벤치마크가 될 수 있고, S&P 500 지수 추종이 벤치마크가 될 수 있다.
#
# 트랜스포머 모델을 사용한 주가 방향성 예측 실습을 통해, 시계열 데이터에서의 패턴 인식과 예측의 가능성을 확인할 수 있었다. 그러나 실전에서는 다양한 정규화 기법과 모델 튜닝이 필요하며, 최종적인 목표는 정확도가 아닌 투자 수익률임을 항상 염두에 두어야 한다.
